# %%
# Importing the needed Libaries 

import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Reading the csv file 

nba = pd.read_csv("nba_2013.csv")
nba
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0        Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1      Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2       Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3     Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4     Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# ..              ...  ..  ...          ...  ..  ..   ...  ...   ...    ...
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      ...  drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# ...

# %%
# To view all the columns

pd.set_option('display.max_columns', None)

# %%
# To view the types of data

nba.dtypes
# Out:
# player           object
# pos              object
# age               int64
# bref_team_id     object
# g                 int64
# gs                int64
# mp                int64
# fg                int64
# fga               int64
# fg.             float64
# x3p               int64
# x3pa              int64
# x3p.            float64
# x2p               int64
# x2pa              int64
# x2p.            float64
# efg.            float64
# ft                int64
# fta               int64
# ft.             float64
# orb               int64
# drb               int64
# trb               int64
# ast               int64
# stl               int64
# blk               int64
# tov               int64
# pf                int64
# pts               int64
# season           object
# season_end        int64
# dtype: object

# %%
# Selecting data types that are objects

nba.select_dtypes(include=["object"])
# Out:
#              player pos bref_team_id     season
# 0        Quincy Acy  SF          TOT  2013-2014
# 1      Steven Adams   C          OKC  2013-2014
# 2       Jeff Adrien  PF          TOT  2013-2014
# 3     Arron Afflalo  SG          ORL  2013-2014
# 4     Alexis Ajinca   C          NOP  2013-2014
# ..              ...  ..          ...        ...
# 476     Tony Wroten  SG          PHI  2013-2014
# 477      Nick Young  SG          LAL  2013-2014
# 478  Thaddeus Young  PF          PHI  2013-2014
# 479     Cody Zeller   C          CHA  2013-2014
# 480    Tyler Zeller   C          CLE  2013-2014
#
# [481 rows x 4 columns]

# %%
# Selecting data that are number data types

nba.select_dtypes(include= ["number"])
# Out:
#      age   g  gs    mp   fg   fga    fg.  x3p  x3pa      x3p.  x2p  x2pa  \
# 0     23  63   0   847   66   141  0.468    4    15  0.266667   62   126
# 1     20  81  20  1197   93   185  0.503    0     0       NaN   93   185
# 2     27  53  12   961  143   275  0.520    0     0       NaN  143   275
# 3     28  73  73  2552  464  1011  0.459  128   300  0.426667  336   711
# 4     25  56  30   951  136   249  0.546    0     1  0.000000  136   248
# ..   ...  ..  ..   ...  ...   ...    ...  ...   ...       ...  ...   ...
# 476   20  72  16  1765  345   808  0.427   40   188  0.212766  305   620
# 477   28  64   9  1810  387   889  0.435  135   350  0.385714  252   539
# 478   25  79  78  2718  582  1283  0.454   90   292  0.308219  492   991
# 479   21  82   3  1416  172   404  0.426    0     1  0.000000  172   403
# 480   24  70   9  1049  156   290  0.538    0     1  0.000000  156   289
#
#          x2p.   efg.   ft  fta    ft.  orb  drb  trb  ast  stl  blk  tov   pf  \
# ...

# %%
# Creating new columns

nba["pts_per_game"] = nba["pts"] / nba["g"]
nba["ast_per_game"] = nba["ast"] / nba["g"]
nba["total_rebound_per_game"] = nba["trb"] / nba['g']
nba
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0        Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1      Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2       Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3     Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4     Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# ..              ...  ..  ...          ...  ..  ..   ...  ...   ...    ...
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      x3p  x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  \
# ...

# %%
# Who are the top 5 scorer per game during the 2013 season?

top_5_scorer = nba.groupby("player")["pts_per_game"].mean().reset_index().sort_values(by= "pts_per_game", ascending=False)
top_5_scorer.head(5)
# Out:
#               player  pts_per_game
# 264     Kevin Durant     32.012346
# 65   Carmelo Anthony     27.428571
# 286     LeBron James     27.129870
# 266       Kevin Love     26.103896
# 195     James Harden     25.356164

# %%
# Which player scored the most points during the 2013 season?

leading_scorer =nba[nba["pts_per_game"]==nba['pts_per_game'].max()]
leading_scorer
# Out:
#            player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  x3p  \
# 133  Kevin Durant  SF   25          OKC  81  81  3122  849  1688  0.503  192
#
#      x3pa      x3p.  x2p  x2pa      x2p.  efg.   ft  fta    ft.  orb  drb  \
# 133   491  0.391039  657  1197  0.548872  0.56  703  805  0.873   58  540
#
#      trb  ast  stl  blk  tov   pf   pts     season  season_end  pts_per_game  \
# 133  598  445  103   59  285  174  2593  2013-2014        2013     32.012346
#
#      ast_per_game  total_rebound_per_game
# 133      5.493827                7.382716

# %%
# Which team did the leading scorer play for? 

leading_scorer.bref_team_id
# Out:
# 133    OKC
# Name: bref_team_id, dtype: object

# %%
# Which positions is leading scorer playing as? 

leading_scorer.pos
# Out:
# 133    SF
# Name: pos, dtype: object

# %%
# How many games did the leading scorer play?

leading_scorer.g
# Out:
# 133    81
# Name: g, dtype: int64

# %%
# Which players scored more than 25 points per game?

scored_more_than_25 = nba[nba["pts_per_game"] > 25]
scored_more_than_25
# Out:
#               player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 17   Carmelo Anthony  PF   29          NYK  77  77  2982  743  1643  0.452
# 133     Kevin Durant  SF   25          OKC  81  81  3122  849  1688  0.503
# 185     James Harden  SG   24          HOU  73  73  2777  549  1205  0.456
# 225     LeBron James  PF   29          MIA  77  77  2902  767  1353  0.567
# 277       Kevin Love  PF   25          MIN  77  77  2797  650  1421  0.457
#
#      x3p  x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  \
# 17   167   415  0.402410  576  1228  0.469055  0.503  459  541  0.848  145
# 133  192   491  0.391039  657  1197  0.548872  0.560  703  805  0.873   58
# 185  177   483  0.366460  372   722  0.515235  0.529  576  665  0.866   61
# 225  116   306  0.379085  651  1047  0.621777  0.610  439  585  0.750   81
# 277  190   505  0.376238  460   916  0.502183  0.524  520  633  0.821  224
#
# ...

# %%
# Which player had the most assist per game?

nba[nba["ast_per_game"]==nba["ast_per_game"].max()]
# Out:
#          player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  x3p  \
# 347  Chris Paul  PG   28          LAC  62  62  2171  406  870  0.467   78
#
#      x3pa      x3p.  x2p  x2pa     x2p.   efg.   ft  fta    ft.  orb  drb  \
# 347   212  0.367925  328   658  0.49848  0.511  295  345  0.855   38  230
#
#      trb  ast  stl  blk  tov   pf   pts     season  season_end  pts_per_game  \
# 347  268  663  154    4  145  157  1185  2013-2014        2013     19.112903
#
#      ast_per_game  total_rebound_per_game
# 347     10.693548                4.322581

# %%
# Which player averaged a double double during the 2013 season.

nba[(nba["pts_per_game"]>10) & (nba["ast_per_game"]>10)]
# Out:
#          player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  x3p  \
# 347  Chris Paul  PG   28          LAC  62  62  2171  406  870  0.467   78
#
#      x3pa      x3p.  x2p  x2pa     x2p.   efg.   ft  fta    ft.  orb  drb  \
# 347   212  0.367925  328   658  0.49848  0.511  295  345  0.855   38  230
#
#      trb  ast  stl  blk  tov   pf   pts     season  season_end  pts_per_game  \
# 347  268  663  154    4  145  157  1185  2013-2014        2013     19.112903
#
#      ast_per_game  total_rebound_per_game
# 347     10.693548                4.322581

# %%
# Using Groupby() function, group the players that played for the Clippers during the 2013 season?

Clippers = nba.groupby('bref_team_id').get_group("LAC")
Clippers
# Out:
#               player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 33       Matt Barnes  SF   33          LAC  63  40  1735  231   527  0.438
# 70    Reggie Bullock  SF   22          LAC  43   0   395   43   121  0.355
# 97   Darren Collison  PG   26          LAC  80  35  2069  324   694  0.467
# 104   Jamal Crawford  SG   33          LAC  69  24  2094  421  1011  0.416
# 130     Jared Dudley  SF   28          LAC  74  43  1729  196   447  0.438
# 178     Willie Green  SG   32          LAC  55   9   869  102   271  0.376
# 179    Blake Griffin  PF   24          LAC  80  80  2863  718  1359  0.528
# 209     Ryan Hollins  PF   29          LAC  61   0   482   53    72  0.736
# 222  Stephen Jackson  SF   35          LAC   9   0   107    6    26  0.231
# 227   Antawn Jamison  PF   37          LAC  22   0   248   29    92  0.315
# 245   DeAndre Jordan   C   25          LAC  82  82  2870  348   515  0.676
# ...

# %%
# Who were the point guard in the Clippers team?

Point_guard = ["PG"]
Clippers[Clippers["pos"].isin(Point_guard)]
# Out:
#               player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  \
# 97   Darren Collison  PG   26          LAC  80  35  2069  324  694  0.467
# 347       Chris Paul  PG   28          LAC  62  62  2171  406  870  0.467
# 456     Maalik Wayns  PG   22          LAC   2   0     9    1    2  0.500
#
#      x3p  x3pa      x3p.  x2p  x2pa     x2p.   efg.   ft  fta    ft.  orb  \
# 97    71   189  0.375661  253   505  0.50099  0.518  192  224  0.857   47
# 347   78   212  0.367925  328   658  0.49848  0.511  295  345  0.855   38
# 456    0     0       NaN    1     2  0.50000  0.500    0    0    NaN    0
#
#      drb  trb  ast  stl  blk  tov   pf   pts     season  season_end  \
# 97   141  188  297   93   15  132  150   911  2013-2014        2013
# 347  230  268  663  154    4  145  157  1185  2013-2014        2013
# 456    2    2    2    2    0    0    4     2  2013-2014        2013
#
#      pts_per_game  ast_per_game  total_rebound_per_game
# ...

# %%
# Which players in the Clippers are younger than 28 years old?

Clippers[Clippers["age"]<28]
# Out:
#               player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 70    Reggie Bullock  SF   22          LAC  43   0   395   43   121  0.355
# 97   Darren Collison  PG   26          LAC  80  35  2069  324   694  0.467
# 179    Blake Griffin  PF   24          LAC  80  80  2863  718  1359  0.528
# 245   DeAndre Jordan   C   25          LAC  82  82  2870  348   515  0.676
# 456     Maalik Wayns  PG   22          LAC   2   0     9    1     2  0.500
#
#      x3p  x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  \
# 70    22    73  0.301370   21    48  0.437500  0.446    7    9  0.778   11
# 97    71   189  0.375661  253   505  0.500990  0.518  192  224  0.857   47
# 179   12    44  0.272727  706  1315  0.536882  0.533  482  674  0.715  192
# 245    0     0       NaN  348   515  0.675728  0.676  160  374  0.428  331
# 456    0     0       NaN    1     2  0.500000  0.500    0    0    NaN    0
#
# ...

# %%
# Which player scored the most points per game in the Clippers?

Clippers[Clippers["pts_per_game"]==Clippers.pts_per_game.max()]
# Out:
#             player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  x3p  \
# 179  Blake Griffin  PF   24          LAC  80  80  2863  718  1359  0.528   12
#
#      x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  drb  \
# 179    44  0.272727  706  1315  0.536882  0.533  482  674  0.715  192  565
#
#      trb  ast  stl  blk  tov   pf   pts     season  season_end  pts_per_game  \
# 179  757  309   92   51  224  265  1930  2013-2014        2013        24.125
#
#      ast_per_game  total_rebound_per_game
# 179        3.8625                  9.4625

# %%
# Which positions scored the most points?

nba.groupby("pos").describe()
# Out:
#        age                                                          g  \
#      count       mean       std   min    25%   50%   75%   max  count
# pos
# C     90.0  26.411111  4.010925  20.0  23.25  26.0  29.0  37.0   90.0
# F      1.0  31.000000       NaN  31.0  31.00  31.0  31.0  31.0    1.0
# G      1.0  26.000000       NaN  26.0  26.00  26.0  26.0  26.0    1.0
# PF    96.0  27.093750  3.885406  21.0  24.00  26.5  30.0  37.0   96.0
# PG    85.0  26.588235  4.218141  20.0  23.00  26.0  29.0  39.0   85.0
# SF    99.0  26.333333  4.147780  19.0  23.00  26.0  28.0  36.0   99.0
# SG   109.0  26.137615  4.655677  19.0  23.00  25.0  29.0  39.0  109.0
#
#                                                              gs             \
#           mean        std  min    25%   50%    75%   max  count       mean
# pos
# C    50.955556  23.994808  2.0  30.25  54.5  71.75  82.0   90.0  25.855556
# F     1.000000        NaN  1.0   1.00   1.0   1.00   1.0    1.0   0.000000
# ...

# %%
# From the previous analysis, filter to only view the 5 tradition positions?

position = ["C", "PF", "SF", "SG", "PG"]

Tradition_position = nba[nba["pos"].isin(position)]
Tradition_position
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0        Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1      Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2       Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3     Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4     Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# ..              ...  ..  ...          ...  ..  ..   ...  ...   ...    ...
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      x3p  x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  \
# ...

# %%
Tradition_position.groupby("pos").pts_per_game.describe()
# Out:
#      count      mean       std  min       25%       50%        75%        max
# pos
# C     90.0  7.198897  5.626477  0.0  2.965909  5.916376  10.419012  22.732394
# PF    96.0  8.591845  6.254250  0.0  4.160880  6.824817  11.738910  27.428571
# PG    85.0  9.667362  6.053228  0.0  4.133333  9.250000  14.296875  24.012821
# SF    99.0  7.448064  5.317530  0.0  3.583333  6.296296   9.983573  32.012346
# SG   109.0  7.893249  5.829948  0.0  2.720000  6.029851  11.938272  25.356164

# %%
matrix = Tradition_position.corr()
matrix
# Out:
#                              age         g        gs        mp        fg  \
# age                     1.000000 -0.008017  0.026955  0.010717 -0.007574
# g                      -0.008017  1.000000  0.609885  0.863734  0.738785
# gs                      0.026955  0.609885  1.000000  0.859815  0.821038
# mp                      0.010717  0.863734  0.859815  1.000000  0.930793
# fg                     -0.007574  0.738785  0.821038  0.930793  1.000000
# fga                    -0.016114  0.745734  0.810914  0.936568  0.988201
# fg.                     0.027236  0.313385  0.230737  0.267250  0.272837
# x3p                     0.052286  0.516537  0.500437  0.643928  0.595914
# x3pa                    0.030580  0.535370  0.514306  0.664957  0.612616
# x3p.                    0.013766  0.095225  0.059861  0.132685  0.105821
# x2p                    -0.026915  0.683359  0.784893  0.863332  0.960679
# x2pa                   -0.034009  0.692871  0.784079  0.873527  0.961882
# ...

# %%
unstack_matrix=matrix.unstack()
unstack_matrix
# Out:
# age                     age                       1.000000
#                         g                        -0.008017
#                         gs                        0.026955
#                         mp                        0.010717
#                         fg                       -0.007574
#                                                     ...
# total_rebound_per_game  pts                       0.611003
#                         season_end                     NaN
#                         pts_per_game              0.624510
#                         ast_per_game              0.206534
#                         total_rebound_per_game    1.000000
# Length: 900, dtype: float64

# %%
sorted_pairs = unstack_matrix.sort_values()
sorted_pairs
# Out:
# orb                     x3p.                     -0.319983
# x3p.                    orb                      -0.319983
# total_rebound_per_game  x3p.                     -0.232421
# x3p.                    total_rebound_per_game   -0.232421
#                         blk                      -0.191613
#                                                     ...
# season_end              ast_per_game                   NaN
#                         total_rebound_per_game         NaN
# pts_per_game            season_end                     NaN
# ast_per_game            season_end                     NaN
# total_rebound_per_game  season_end                     NaN
# Length: 900, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>.5]
high_corr
# Out:
# gs                      x3p                       0.500437
# x3p                     gs                        0.500437
# ft                      x3p                       0.501950
# x3p                     ft                        0.501950
# pts                     orb                       0.503553
#                                                     ...
# tov                     tov                       1.000000
# pf                      pf                        1.000000
# pts                     pts                       1.000000
# efg.                    efg.                      1.000000
# total_rebound_per_game  total_rebound_per_game    1.000000
# Length: 447, dtype: float64

# %%
position = ["C", "PF", "SF", "SG", "PG"]

Tradition_position = nba[nba["pos"].isin(position)]
Tradition_position
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0        Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1      Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2       Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3     Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4     Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# ..              ...  ..  ...          ...  ..  ..   ...  ...   ...    ...
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      x3p  x3pa      x3p.  x2p  x2pa      x2p.   efg.   ft  fta    ft.  orb  \
# ...

# %%
# Comparing the points per game according to each of the five positions.

ts_per_position = nba[["pos","pts_per_game"]]
position = ["C", "PF", "SF", "SG", "PG"]

pts_per_position = pts_per_position[pts_per_position["pos"].isin(position)]
pts_per_position
# Out:
#     pos  pts_per_game
# 0    SF      2.714286
# 1     C      3.271605
# 2    PF      6.830189
# 3    SG     18.219178
# 4     C      5.857143
# ..   ..           ...
# 476  SG     13.041667
# 477  SG     17.875000
# 478  PF     17.936709
# 479   C      5.975610
# 480   C      5.700000
#
# [479 rows x 2 columns]

# %%
pts_per_position["pts_per_game"].hist(by=pts_per_position["pos"])
# Out:
# array([[<AxesSubplot:title={'center':'C'}>,
#         <AxesSubplot:title={'center':'PF'}>],
#        [<AxesSubplot:title={'center':'PG'}>,
#         <AxesSubplot:title={'center':'SF'}>],
#        [<AxesSubplot:title={'center':'SG'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
pts_per_position["pts_per_game"].hist(by = pts_per_position["pos"], layout =(1,5))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
# Histogram of points per game according to each positions.

pts_per_position["pts_per_game"].hist(by = pts_per_position["pos"], layout =(1,5), figsize=(16,5))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
# Using seaborn for data visualization 

import seaborn as sns
import matplotlib.pyplot as plt
